# %% [markdown]
# ## Dependencies

# %%
import os
import torch
from utils import train_UNet_multiclass,BraTsDataset
from model1 import UNet3D
from torch.utils.data import DataLoader
from model7 import MobileNetV3UNet3D


# parameters
device = 'cuda' if torch.cuda.is_available() else 'cpu'
lr = 1e-3
num_epochs=500
patience = 50
batch_size = 4
num_classes = 4
torch.manual_seed(42)

# Paths
train_img_dir = f"../data/brats20/train_data_3channel/train/images/"
train_masks_dir = f"../data/brats20/train_data_3channel/train/masks/"
val_img_dir = f"../data/brats20/train_data_3channel/val/images/"
val_mask_dir = f"../data/brats20/train_data_3channel/val/masks/"


os.makedirs('./logs',exist_ok=True)
os.makedirs('./saved_models',exist_ok=True)

model_path_1 = './saved_models/unet3d.pt'
log_path_1 = './logs/train_unet3d.csv'
model_path_7 = './saved_models/mobilenet3d.pt'
log_path_7 = './logs/train_mobilenet3d.csv'
# Out:
# Segmentation Models: using `keras` framework.

# %% [markdown]
# ## Load Dataset

# %%
train_data = BraTsDataset(img_dir=train_img_dir,
                          img_list=os.listdir(train_img_dir),
                          mask_dir=train_masks_dir,
                          mask_list=os.listdir(train_masks_dir))

val_data = BraTsDataset(img_dir=val_img_dir,
                        img_list=os.listdir(val_img_dir),
                        mask_dir=val_mask_dir,
                        mask_list=os.listdir(val_mask_dir))

train_loader = DataLoader(dataset=train_data,
                          batch_size=batch_size,
                          shuffle=True)
val_loader = DataLoader(dataset=val_data,
                        batch_size=batch_size)

# %%
for img,mask in train_loader:
    print(img.shape,mask.shape)
    break
# Out:
# torch.Size([4, 3, 128, 128, 128]) torch.Size([4, 128, 128, 128])

# %% [markdown]
# ## Train

# %% [markdown]
# ### Model 1

# %%
model_1 = UNet3D()
train_UNet_multiclass(model=model_1,
                      train_loader=train_loader,
                      valid_loader=val_loader,
                      device=device,
                      num_classes=num_classes,
                      num_epochs=num_epochs,
                      lr=lr,
                      log_path=log_path_1,
                      model_path=model_path_1,
                      patience=patience)
# Out:
# Epoch 1/500 | Train Loss: 1.1109 | Valid Loss: 0.8596 | Valid Dice: 0.2436 | Patience: 0
# Epoch 2 [Training]:  14%|█▍        | 9/65 [02:24<15:02, 16.12s/it]

# %% [markdown]
# ## Model 7

# %%
model_7 = MobileNetV3UNet3D(in_channels=3,out_channels=4)
train_UNet_multiclass(model=model_7,
                      train_loader=train_loader,
                      valid_loader=val_loader,
                      device=device,
                      num_classes=num_classes,
                      num_epochs=num_epochs,
                      lr=lr,
                      log_path=log_path_7,
                      model_path=model_path_7,
                      patience=patience)
# Out:
# Epoch 1/500 | Train Loss: 1.7364 | Valid Loss: 1.1095 | Valid Dice: 0.3564 | Patience: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 model_7 = MobileNetV3UNet3D(in_channels=3,out_channels=4)
# ----> 2 train_UNet_multiclass(model=model_7,
#       3                       train_loader=train_loader,
#       4                       valid_loader=val_loader,
#       5                       device=device,
#       6                       num_classes=num_classes,
#       7                       num_epochs=num_epochs,
#       8                       lr=lr,
#       9                       log_path=log_path_7,
#      10                       model_path=model_path_7,
#      11                       patience=patience)
#
# File c:\Projects\python\brain_tumor_segmentation\3D\utils.py:70, in train_UNet_multiclass(model, train_loader, valid_loader, device, num_classes, num_epochs, lr, log_path, model_path, patience, losses)
#      68 outputs = model(images)
#      69 loss = criterion(outputs, masks)
# ---> 70 loss.backward()
#      71 optimizer.step()
#      73 batch_size_curr = images.size(0)
#
# File c:\Projects\python\brain_tumor_segmentation\mainenv\Lib\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File c:\Projects\python\brain_tumor_segmentation\mainenv\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Projects\python\brain_tumor_segmentation\mainenv\Lib\site-packages\torch\autograd\graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:
